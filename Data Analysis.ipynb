# %%
import pandas as pd
import matplotlib.pyplot as plt
import folium
import ee

# %%
df = pd.read_csv("D:\SANDI\DEEP LEARNING\HEALTH ASSESSMENT\CSV\\20204121C.csv")

# %%
df.head()
# Out:
#     LONGITUDE  LATITUDE  NEAR_FID  NEAR_DIST  Class  Confidence  \
# 0  112.367383 -2.900250        -1       -1.0      1    0.932026
# 1  112.367521 -2.900250        -1       -1.0      1    0.960157
# 2  112.367250 -2.900238        -1       -1.0      1    0.922938
# 3  112.367104 -2.900222        -1       -1.0      1    0.954527
# 4  112.366959 -2.900221        -1       -1.0      1    0.941227
#
#             Xmin           Xmax          Ymin          Ymax    ...      \
# 0  651972.030788  651980.729137  9.679336e+06  9.679345e+06    ...
# 1  651987.046380  651996.336128  9.679336e+06  9.679345e+06    ...
# 2  651957.797920  651965.442736  9.679337e+06  9.679347e+06    ...
# 3  651940.837512  651949.754765  9.679339e+06  9.679349e+06    ...
# 4  651924.723191  651933.640696  9.679339e+06  9.679349e+06    ...
#
#           R  BUFF_DIST  OBJECTID  BLOCK_CODE     SPMON BLOCK_NAME WERKS  \
# 0  4.582174   4.582174      1100         260  1/2/2020        G19  4122
# ...

# %%
df.
# Out:
#           LONGITUDE      LATITUDE  NEAR_FID  NEAR_DIST    Class    Confidence  \
# count  90092.000000  90092.000000   90092.0    90092.0  90092.0  90092.000000
# mean     112.373673     -2.886817      -1.0       -1.0      1.0      0.983271
# std        0.007065      0.007268       0.0        0.0      0.0      0.024615
# min      112.357307     -2.900477      -1.0       -1.0      1.0      0.205860
# 25%      112.368721     -2.892478      -1.0       -1.0      1.0      0.980957
# 50%      112.374437     -2.886618      -1.0       -1.0      1.0      0.987815
# 75%      112.379656     -2.881243      -1.0       -1.0      1.0      0.992286
# max      112.384447     -2.870065      -1.0       -1.0      1.0      0.999858
#
#                 Xmin           Xmax          Ymin          Ymax            Dg  \
# count   90092.000000   90092.000000  9.009200e+04  9.009200e+04  90092.000000
# mean   652672.878316  652681.967010  9.680821e+06  9.680830e+06     12.896285
# ...

# %%
df['R'].hist()

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.scatter(df['LONGITUDE'], df['LATITUDE'], c=df['RASTERVALU'], cmap='RdYlGn')
plt.xlim(112.360, 112.368)
plt.ylim(-2.88, -2.89)
plt.show()

# %%
map = folium.Map(location=[-2.88, 112.360], control_scale=True, zoom_control=True, zoom_start=15, tiles='Mapbox Bright')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data = df.to_json(
